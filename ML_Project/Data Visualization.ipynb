# %%
from scipy.io import loadmat, whosmat
import numpy as np
import pandas as pd
from pyswarm import pso
from sklearn.svm import SVR
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import datetime
import json
import os
import math

# %%
path = './data_json/'
with open(path+'B0006_impedance.json') as f:    
    impedance_data = json.load(f)
    
with open(path+'B0006_discharge.json') as f:    
    discharge_data = json.load(f)
    
with open(path+'B0006_charge.json') as f:    
    charge_data = json.load(f)

# %%
for cycle in impedance_data.keys():
    plt.plot(cycle, impedance_data[cycle]["rct"], 'o')
    plt.ylabel('Charge transfer resistance')
    plt.xlabel('Cycle number')
    plt.title('Battery B0006')
plt.show()

# %% [markdown]
# ## Discharge: Temp vs Time

# %%
for cycle in discharge_data.keys():
    plt.plot(discharge_data[cycle]["time"], discharge_data[cycle]["temp_battery"], '-')
    plt.ylabel('Temp')
    plt.xlabel('Time (s)')
plt.show()

# %% [markdown]
# ## Discharge: Voltage vs Time

# %%
for cycle in discharge_data.keys():
    plt.plot(discharge_data[cycle]["time"], discharge_data[cycle]["voltage_battery"], '-')
    plt.ylabel('Voltage')
    plt.xlabel('Time (s)')
plt.show()

# %% [markdown]
# ## Charge: Temp vs Time

# %%
for cycle in charge_data.keys():
    plt.plot(charge_data[cycle]["time"], charge_data[cycle]["temp_battery"], '-')
    plt.ylabel('Temp')
    plt.xlabel('Time (s)')
plt.show()

# %% [markdown]
# ## Charge: Voltage vs Time

# %%
for cycle in charge_data.keys():
    plt.plot(charge_data[cycle]["time"], charge_data[cycle]["voltage_battery"], '-')
    plt.ylabel('Voltage')
    plt.xlabel('Time (s)')
plt.show()

# %% [markdown]
# ## Capacity Degradation

# %%
# files = ['B0007','B0005','B0006','B0018']
c = ['r','b','g','y','c','k']

for d,col in zip(files,c):
    with open(path+d+'_discharge.json') as f:    
        discharge_data = json.load(f)

    for cycle in discharge_data.keys():

        plt.plot(int(cycle), discharge_data[cycle]["capacity"][0], col+'.')
        plt.ylabel('Actual_Capacity')
        plt.xlabel('Cycles (s)')

plt.figure(figsize=(70,80))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5323c03b45cd> in <module>
#       3
#       4 for d,col in zip(files,c):
# ----> 5     with open(path+d+'_discharge.json') as f:
#       6         discharge_data = json.load(f)
#       7
#
# NameError: name 'path' is not defined
